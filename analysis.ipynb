# %%
import pandas as pd
import seaborn as sns

# %%
# reading the dataframe
jan = pd.read_csv('202301-divvy-tripdata/202301-divvy-tripdata.csv')
feb = pd.read_csv('202302-divvy-tripdata/202302-divvy-tripdata.csv')
mar = pd.read_csv('202303-divvy-tripdata/202303-divvy-tripdata.csv')
apr = pd.read_csv('202304-divvy-tripdata/202304-divvy-tripdata.csv')
may = pd.read_csv('202305-divvy-tripdata/202305-divvy-tripdata.csv')
jun = pd.read_csv('202306-divvy-tripdata/202306-divvy-tripdata.csv')
jul = pd.read_csv('202307-divvy-tripdata/202307-divvy-tripdata.csv')
aug = pd.read_csv('202308-divvy-tripdata/202308-divvy-tripdata.csv')
sep = pd.read_csv('202309-divvy-tripdata/202309-divvy-tripdata.csv')
oct = pd.read_csv('202310-divvy-tripdata/202310-divvy-tripdata.csv')
nov = pd.read_csv('202311-divvy-tripdata/202311-divvy-tripdata.csv')
dec = pd.read_csv('202312-divvy-tripdata/202312-divvy-tripdata.csv')

# %%
months = [jan, feb, mar, apr, may, jun, jul, aug, sep, oct, nov, dec]
df = pd.concat(months)

# %%
df
# Out:
#                  ride_id  rideable_type           started_at  \
# 0       F96D5A74A3E41399  electric_bike  2023-01-21 20:05:42
# 1       13CB7EB698CEDB88   classic_bike  2023-01-10 15:37:36
# 2       BD88A2E670661CE5  electric_bike  2023-01-02 07:51:57
# 3       C90792D034FED968   classic_bike  2023-01-22 10:52:58
# 4       3397017529188E8A   classic_bike  2023-01-12 13:58:01
# ...                  ...            ...                  ...
# 224068  F74DF9549B504A6B  electric_bike  2023-12-07 13:15:24
# 224069  BCDA66E761CC1029   classic_bike  2023-12-08 18:42:21
# 224070  D2CF330F9C266683   classic_bike  2023-12-05 14:09:11
# 224071  3829A0D1E00EE970  electric_bike  2023-12-02 21:36:07
# 224072  A373F5B447AEA508   classic_bike  2023-12-11 13:07:46
#
#                    ended_at           start_station_name start_station_id  \
# 0       2023-01-21 20:16:33  Lincoln Ave & Fullerton Ave     TA1309000058
# 1       2023-01-10 15:46:05        Kimbark Ave & 53rd St     TA1309000037
# ...
